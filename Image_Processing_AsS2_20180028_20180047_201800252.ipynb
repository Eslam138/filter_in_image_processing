# %% [markdown]
# # Ahmed Mohamed Abdel-Rashied 20180028
# # Eslam Nasser Ghoneim 20180047
# # Mahmoud Ramadan Sayed 20180252

# %%
import random
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np

def add_noise(img):

	row , col = img.shape
	number_of_pixels = random.randint(100, 400)
	for i in range(number_of_pixels):
	
		y_coord=random.randint(0, row - 1)
		
		x_coord=random.randint(0, col - 1)
		
		img[y_coord][x_coord] = 255
		
	number_of_pixels = random.randint(100 , 400)
	for i in range(number_of_pixels):
	
		y_coord=random.randint(0, row - 1)
		
		x_coord=random.randint(0, col - 1)
		
		img[y_coord][x_coord] = 0
		
	return img

img = cv2.imread('/content/WATbI (1).png',
				cv2.IMREAD_GRAYSCALE)

#Storing the image
cv2.imwrite('salt-and-pepper-lena.jpg',
			add_noise(img))
# Out:
# True

# %%
img = cv2.imread('salt-and-pepper-lena.jpg',
				cv2.IMREAD_GRAYSCALE)
fig, ax = plt.subplots()

ax.imshow(img)

plt.show()

# %% [markdown]
# # smoothing

# %% [markdown]
# ## mean

# %%
blur = cv2.blur(img,(5,5))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv2.blur(img,(3,3))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv2.blur(img,(10,10))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## median

# %%
median = cv2.medianBlur(img,5)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
median = cv2.medianBlur(img,3)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
median = cv2.medianBlur(img,7)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Rank

# %%
from PIL import Image, ImageFilter 
     
# creating a image object 
im1 = Image.open(r"/content/salt-and-pepper-lena.jpg") 
     
# applying the rank filter 
im2 = im1.filter(ImageFilter.RankFilter(size = 3, rank = 0)) 
     
plt.subplot(121),plt.imshow(im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(im2),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# applying the rank filter 
im2 = im1.filter(ImageFilter.RankFilter(size = 3, rank = 5)) 
     
plt.subplot(121),plt.imshow(im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(im2),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# applying the rank filter 
im2 = im1.filter(ImageFilter.RankFilter(size = 3, rank = 8)) 
     
plt.subplot(121),plt.imshow(im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(im2),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# applying the rank filter 
im2 = im1.filter(ImageFilter.RankFilter(size = 3, rank = 6)) 
     
plt.subplot(121),plt.imshow(im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(im2),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# applying the rank filter 
im2 = im1.filter(ImageFilter.RankFilter(size = 5, rank = 6)) 
     
plt.subplot(121),plt.imshow(im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(im2),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# applying the rank filter 
im2 = im1.filter(ImageFilter.RankFilter(size = 7, rank = 6)) 
     
plt.subplot(121),plt.imshow(im1),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(im2),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Explain briefly the following questions:
# ### Which smoothing filter removes the noise in a better way? Why?
#
#
# >  median filter is the best
#
# >> median is the middle number in a sorted array of pixels
# ### What is the effect of changing the window size
# > Large window size generally leads to blurred images especially images that contain a lot of edges
# ### When utilizing the rank order filter, what is the effect of changing the rank?
#
#
# > low rank will remove a  salt noise and hiegh rank will remove a  pepper noise, So we should choose any rank close tm mean or median

# %%
img = cv2.imread('/content/WATbI (1).png',
				cv2.IMREAD_GRAYSCALE)

x=np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
y=np.array([[-1,0,1],[-1,0,1],[-1,0,1]])

dstx = cv2.filter2D(img, -1, x)
dsty = cv2.filter2D(img, -1, y)
dstxy=dstx+dsty
img2=np.hstack((img,dstx,dstx))
plt.imshow(dstxy)
plt.show()

# %%
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()
